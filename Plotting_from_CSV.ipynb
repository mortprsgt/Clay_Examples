# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = pd.read_csv('npsam.csv',index_col=0)

# %%
data.plot(legend=False)

# %%
data.ix[800.0:950.0].plot(legend=False)

sliced = data.ix[800.0:950.0]
dark = sliced.mean(axis = 1).mean()

dark
# Out:
# 185.21905236028215

# %%
no_dark = data-dark
no_dark.plot(legend=False)

# %%
no_dark.ix[440.0:700.0].plot(legend = False, linewidth = 1.5)

# %%
no_dark.ix[440.0:700.0].plot(legend=False, color = 'r', linewidth=1)

# %% [markdown]
# data

# %% [markdown]
# ### AT THIS POINT, MAKE SURE YOU ARE USING THE SLICED WAVE

# %%
ref = no_dark[no_dark.columns[0]]
ref = ref.loc[440:680]
no_dark = no_dark.loc[440:680]
ref.plot(title='REFERENCE SPECTRA (First column)')

# %%
f, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3, figsize=(10,10))


data_1 = no_dark.iloc[:,0:12]
abs_1 = data_1.divide(data_1.iloc[:,0], axis=0)
abs_1.plot(ax=ax1,legend=False)


data_2 = no_dark.iloc[:,12:25]
abs_2 = data_2.divide(data_2.iloc[:,0], axis=0)
abs_2.plot(ax=ax2,legend=False)

data_3 = no_dark.iloc[:,25:38]
abs_3 = data_3.divide(data_3.iloc[:,0], axis=0)
abs_3.plot(ax=ax3,legend=False)

data_4 = no_dark.iloc[:,38:51]
abs_4 = data_4.divide(data_4.iloc[:,0], axis=0)
abs_4.plot(ax=ax4,legend=False)

data_5 = no_dark.iloc[:,51:63]
abs_5 = data_5.divide(data_5.iloc[:,0], axis=0)
abs_5.plot(ax=ax5,legend=False)

data_6 = no_dark.iloc[:,63:76]
abs_6 = data_6.divide(data_6.iloc[:,0], axis=0)
abs_6.plot(ax=ax6,legend=False)

# %%
print 'Hello World'
# Out:
# Hello World
